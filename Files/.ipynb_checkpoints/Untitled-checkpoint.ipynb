# %%
import json

# The coded form of the text
coded_text = r"\ud835\udc17\ud835\udc08\ud835\udc17\nRIT'23\n~Reality is an illusion~\n\ud83d\udee0\ufe0f \u0040geoaudio"

# Convert the coded text to the original text using json.loads()
original_text = json.loads('"' + coded_text.replace('"', '\\"') + '"')

# Print the original text
print(original_text)
print(len(original_text))
# Out:
# 𝐗𝐈𝐗
# RIT'23
# ~Reality is an illusion~
# 🛠️ @geoaudio
# 48

# %%
#abandoned bs scrap 

import requests
from bs4 import BeautifulSoup

# Replace with the username you want to scrape
username = 'example_username'

# Define the URL to scrape
url = f'https://www.instagram.com/artistpng/'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the og:description meta tag
    meta_tag = soup.find('meta', {'property': 'og:description'})

    # Check if the meta tag was found before accessing its content attribute
    if meta_tag:
        content = meta_tag.get('content')

        # Print the content to debug the issue
        print(f"Content: {content}")

        # Extract the follower count, following count, and number of posts from the content
        parts = content.split(' - ')

        # Print the parts list to debug the issue
        print(f"Parts: {parts}")

        followers = parts[0].split()[0]
        following = parts[1].split()[0]
        posts = parts[2].split()[0]

        # Print out the public data
        print(f"Followers: {followers}")
        print(f"Following: {following}")
        print(f"Number of posts: {posts}")
    else:
        print("Could not find the public data")
else:
    # If the request was unsuccessful, print an error message
    print(f"Error: {response.status_code}")

# %%
import requests
from bs4 import BeautifulSoup


# The URL of the Instagram profile
url = "https://privatephotoviewer.com/usr/creativekerala"

# Send a GET request to the URL and get the HTML content
response = requests.get(url)
html_content = response.text

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, "html.parser")



# Find if any pics are publically  available
pics = str(soup.find('div', {'class': 'pic'}))
print(pics)

#print(soup)
# Out:
# <span class="profile-posts">10 </span> 10
# None
#
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.8.1/css/all.css" integrity="sha384-50oBUHEmvpQ+1lW4y57PTFmhCaXp0ML5d60M1M7uH2+nqUivzIebhndOJK28anvf" rel="stylesheet"/>
# <link href="https://avatars2.githubusercontent.com/u/38456916?s=460&amp;u=7db06c46c3c24a2cf19cb793aa8fbb24aedf18d0&amp;v=4" rel="shortcut icon" type="image/x-icon"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js"></script>
# <link href="https://privatephotoviewer.com/css/style.css" rel="stylesheet"/>
# <title>@creativekerala Creative Kerala™ Instagram Profile</title>
# <meta content="Watch @creativekerala- Instagram Photos &amp; Videos  " name="description">
# <meta content=" @creativekerala- On Instagram  " name="keywords">
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-39FLRGHS33"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'G-39FLRGHS33');
#     </script>
# <script>
#     function getOS() {
# 	  var userAgent = window.navigator.userAgent,
# 		  platform = window.navigator?.userAgentData?.platform || window.navigator.platform,
# 		  macosPlatforms = ['Macintosh', 'MacIntel', 'MacPPC', 'Mac68K'],
# 		  windowsPlatforms = ['Win32', 'Win64', 'Windows', 'WinCE'],
# 		  iosPlatforms = ['iPhone', 'iPad', 'iPod'],
# 		  os = null;
#
# 	  if (macosPlatforms.indexOf(platform) !== -1) {
# 		os = 'Mac OS';
# 	  } else if (iosPlatforms.indexOf(platform) !== -1) {
# 		os = 'iOS';
# 	  } else if (windowsPlatforms.indexOf(platform) !== -1) {
# 		os = 'Windows';
# 		document.getElementById('cta2').style.display = "";
# 	  } else if (/Android/.test(userAgent)) {
# 		os = 'Android';
# 	  } else if (/Linux/.test(platform)) {
# 		os = 'Linux';
# 	  }
#
# 	  return os;
# 	}
#
#     </script>
# </meta></meta></head>
# <body>
# <div class="page">
# <header>
# <div class="head-inner-wrap">
# <div class="logo">
# <a href="https://privatephotoviewer.com/" target="_blank">
# <i class="fa fa-camera-retro"></i>
# </a>
# </div>
# <div class="search-bar2">
# <form action="https://privatephotoviewer.com/search.php" method="post">
# <input id="search" name="find" placeholder="Search users &amp; stories on Instagram" type="search"/>
# <button class="cta" type="submit">
# <i class="fa fa-search" type="submit"></i> Search
# </button>
# </form>
# </div>
# </div>
# </header>
# <div class="profile-wrap mb-2rem">
# <div class="profile-avatar">
# <div class="circ-story circ-gradient"></div>
# <img alt="" id="myImg" src="https://cdn.privatephotoviewer.com/img.php?img=https%3A%2F%2Finstagram.fhan5-9.fna.fbcdn.net%2Fv%2Ft51.2885-19%2F38011622_267642184063425_8291999483839905792_n.jpg%3Fstp%3Ddst-jpg_s320x320%26_nc_ht%3Dinstagram.fhan5-9.fna.fbcdn.net%26_nc_cat%3D109%26_nc_ohc%3DbC-6a9CVMYcAX_Lf0iV%26edm%3DAOQ1c0wBAAAA%26ccb%3D7-5%26oh%3D00_AfDWzSWJF22uq3eju9wOriom257ZdbxufuKzKw4P8eWONw%26oe%3D64432F67%26_nc_sid%3D8fd12b"/>
# </div>
# <div class="profile-info">
# <div class="profile-title mb-1rem">
# <h2>@creativekerala </h2>
# <button class="cta">Share</button>
# </div>
# Profile Stats
# <ul class="profile-numbers mb-1rem">
# <li>
# <a href="#">
# <span class="profile-posts">10 </span>
# posts
# </a>
# </li>
# <li>
# <a href="#">
# <span class="profile-followers">12 </span>
# followers
# </a>
# </li>
# <li>
# <a href="#">
# <span class="profile-following">7</span>
# following
# </a>
# </li>
# </ul>
# <div class="profile-bio">
# <h1 class="profile-name">Creative Kerala™</h1>
# <span class="profile-desc">
# A page to support the rising creative minds✨
# •
# •
# •
# Use tag #c_kerala or DM us to get featured.
# </span>
# </div>
# </div>
# </div>
# <ul class="profile-numbers responsive-profile">
# <li>
# <a href="#">
# <span class="profile-posts" id="posttoal">10 </span>
# Posts
# </a>
# </li>
# <li>
# <a href="#">
# <span class="profile-followers">12 </span>
# Followers
# </a>
# </li>
# <li>
# <a href="#">
# <span class="profile-following">7</span>
# Following
# </a>
# </li>
# </ul>
# <div class="gallery-pics inner-wrap" id="unlocker" style="padding-top:10px;padding-bottom:10px;">
# <button class="cta" onclick="loadingShow();" style="display: block;margin-left: auto;margin-right: auto;">Unlock Private Photo</button>
# </div>
# <div class="gallery-pics inner-wrap" id="verify" style="padding-top:10px;padding-bottom:10px;display:none;">
# <p style="display: block;margin-left: auto;margin-right: auto;">Complete Human Verify To View Hidden Photo</p>
# <button class="cta" onclick="CPABuildLock();" style="display: block;margin-left: auto;margin-right: auto;">Verify</button>
# <br/>
# //function gogogo(){location.replace("https://href.li/?https://systemupgrade.info/S18MfzGt")}
# <center><button class="cta" id="cta2" onclick="gogogo()" style="display: none;margin-left: auto;margin-right: auto;">Download Instaker-V5</button></center>';
# //}
# //?&gt;
# </div>
# <div class="gallery-pics inner-wrap">
# <div class="pic-wrap" id="result">
# </div>
# </div>
# <div class="gallery-pics inner-wrap">
# <div class="pic-wrap">
# </div>
# </div>
# <div class="gallery-pics inner-wrap">
# <span class="profile-desc">You are current view Instagram Profile of Creative Kerala™ with username : @creativekerala. </span>
# <span class="profile-desc">If you are happy with this reports, please share it to your friends. </span>
# </div>
# <footer class="inner-wrap">
# <nav>
# <ul class="links">
# <li><a class="nav-link" href="https://privatephotoviewer.com/">Instagram Story Viewer</a></li>
# <li><a class="nav-link" href="https://privatephotoviewer.com/instagram-downloader/">Downloader</a></li>
# <li><a class="nav-link" href="https://privatephotoviewer.com/free-instagram-followers/">Free Instagram Followers</a></li>
# <li><a class="nav-link" href="https://privatephotoviewer.com/instagram-plus-apk-download/">Plus</a></li>
# <li><a class="nav-link" href="https://privatephotoviewer.com/category/guide/">Blog</a></li>
# <li><a class="type--fine-print" href="https://privatephotoviewer.com/privacy-policy/">Privacy Policy</a></li>
# <li><a class="type--fine-print" href="https://privatephotoviewer.com/about-us/">Contact</a></li>
# <li><a class="type--fine-print" href="/popular-users/">Popular Users</a></li>
# </ul>
# </nav>
# <span>
# © 2022 PrivatePhotoviewer.com Version 3.0
# </span>
# </footer>
# <div class="modal" id="myModal">
# <span class="close">×</span>
# <img class="modal-content" id="img01"/>
# <div id="caption"></div>
# </div>
# <div class="gallery-pics inner-wrap">
# <span style="font-size: 7px;">
# This product uses the Instagram API but is not endorsed or certified by Instagram. All Instagram™ logos and trademarks displayed on this application are property of Instagram.
# </span>
# </div>
# </div>
# <script src="https://code.jquery.com/jquery-1.10.2.js"></script>
# <script src="https://privatephotoviewer.com/template/chance.min.js"></script>
# <script src="https://privatephotoviewer.com/template/semantic.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/sweetalert2@8"></script>
# <script>
#
#
#     function loadingShow(){
#     let timerInterval
#     Swal.fire({
#     title: 'Unlocking photo',
#     html: 'It will take few seconds to Unlock Photo',
#     timer: 5000,
#     onBeforeOpen: () => {
#     Swal.showLoading()
#     timerInterval = setInterval(() => {
#         Swal.getContent().querySelector('strong')
#         .textContent = Swal.getTimerLeft()
#     }, 100)
#     },
#     onClose: () => {
#     clearInterval(timerInterval)
#     console.log('asd');
#     imgShow();
#     }
#     }).then((result) => {
#     if (
#     // Read more about handling dismissals
#     result.dismiss === Swal.DismissReason.timer
#     ) {
#     // step4();
#
#
#     }
#     })
#
#     }
#
# function imgShow(){
# //     $element.html('Download')
# //   $element.removeAttr('data-progress')
# //   $element.on('click', $self.OnStart)
# 	getOS()
#   $("#verify").append('<p><i class="material-icons" style="position: relative; top: 2px;align: center;">lock_open</i> Unlocked by PrivatePhotoViewer.Com </p>');
#
#   var media = 10;
#
#   console.log(media);
#   if (media != 0){
#       var images = chance.n(chance.integer, parseInt(media));
#
#       console.log(images);
#
#       images.forEach(function(xD) {
#     var rand = Math.floor(Math.random() * (62 - 1 + 1)) + 1;
#     $('#unlocker').remove();
#
#     $('#result').append('<div class="pic"> <div class="opacity-overlay"> <img alt="" class="border--round" src="https://privatephotoviewer.com/img/flick (' + rand.toString() + ').jpg"> </div>  </div> </div>');
#
#   }
# )
#
#     $('#verify').show();
#
#
#     }
#
# }
#
#
# </script>
# <script type="text/javascript">
# // Get the modal
#     var modal = document.getElementById("myModal");
#
#     // Get the image and insert it inside the modal - use its "alt" text as a caption
#     var img = document.getElementById("myImg");
#     var modalImg = document.getElementById("img01");
#     var captionText = document.getElementById("caption");
#     img.onclick = function(){
#     console.log('ok')
#     modal.style.display = "block";
#     modalImg.src = this.src;
#     captionText.innerHTML = this.alt;
#     }
#     function show(data){
#         modal.style.display = "block";
#         modalImg.src = data.src;
#         captionText.innerHTML = '<p>'+data.alt+'</p></br><center><button class="cta" onclick="CPABuildLock()">Download</button></center>';
#     }
#
#     // Get the <span> element that closes the modal
#     var span = document.getElementsByClassName("close")[0];
#
#     // When the user clicks on <span> (x), close the modal
#     span.onclick = function() {
#     modal.style.display = "none";
#     }
# </script>
# <script type="text/javascript">
#     var CPABUILDSETTINGS={"it":605146,"key":"43068"};
# </script>
# <script src="https://dby7kx9z9yzse.cloudfront.net/0a0ce11.js"></script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'7b9aac539eebf323',m:'uI3.JbkrYIpFAXgrpZH32xSahOC4Nm6Rid8jTafuk.U-1681797477-0-ARjLSjLE5j9HS91kX+U9VvjVj/95SFNYp8YFhemC233K',u:'/cdn-cgi/challenge-platform/h/b'};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>
